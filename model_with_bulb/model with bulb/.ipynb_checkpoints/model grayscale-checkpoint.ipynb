# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from pathlib import Path
print(tf.__version__)
# Out:
# 2.6.0

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
ds_train=tf.keras.preprocessing.image_dataset_from_directory(
    'e-waste pictures/',
    labels='inferred',
    label_mode='int',
    class_names=['battery','controller','bulb','phone'],
    color_mode='grayscale',
    batch_size=batch_size,
    image_size=(img_height,img_width),
    shuffle=True,
    seed=123,
    validation_split=0.2,
    subset="training",
)
# Out:
# Found 164 files belonging to 4 classes.
# Using 132 files for training.

# %%
ds_val = tf.keras.preprocessing.image_dataset_from_directory(
    'e-waste pictures/',
    labels='inferred',
    label_mode='int',
    class_names=['battery','controller','bulb','phone'],
    color_mode='grayscale',
    batch_size=batch_size,
    image_size=(img_height,img_width),
    shuffle=True,
    seed=123,
    validation_split=0.2,
    subset="validation",
)
# Out:
# Found 164 files belonging to 4 classes.
# Using 32 files for validation.

# %%
class_names = np.array(ds_train.class_names)
print(class_names)
# Out:
# ['battery' 'controller' 'bulb' 'phone']

# %%
for image_batch, labels_batch in ds_train:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 180, 180, 1)
# (32,)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
for images, labels in ds_train.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
AUTOTUNE = tf.data.AUTOTUNE
ds_train = ds_train.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
ds_val = ds_val.cache().prefetch(buffer_size=AUTOTUNE)

# %%
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal_and_vertical",
                      input_shape=(img_height,
                                  img_width,
                                  1)),
    layers.RandomRotation(0.3),
    ##layers.RandomZoom(
        ##height_factor=(-0.5, 0),
        ##width_factor=(-0.5, 0)),

  ]
)

# %%
plt.figure(figsize=(10, 10))
for images, _ in ds_train.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %%
num_classes = len(class_names)

model = Sequential([
  data_augmentation,
  layers.Rescaling(1./255,input_shape = (img_height, img_width, 1)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 180, 180, 1)       0
# _________________________________________________________________
# rescaling (Rescaling)        (None, 180, 180, 1)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 180, 180, 16)      160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 90, 90, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 90, 90, 32)        4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 45, 45, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 45, 45, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 22, 22, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 30976)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               3965056
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 516
# =================================================================
# Total params: 3,988,868
# Trainable params: 3,988,868
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs=50
history = model.fit(
  ds_train,
  validation_data=ds_val,
  epochs=epochs
)
# Out:
# Epoch 1/50
# 5/5 [==============================] - 6s 139ms/step - loss: 1.5586 - accuracy: 0.2803 - val_loss: 1.4372 - val_accuracy: 0.3125
# Epoch 2/50
# 5/5 [==============================] - 0s 14ms/step - loss: 1.3723 - accuracy: 0.3333 - val_loss: 1.3410 - val_accuracy: 0.4688
# Epoch 3/50
# 5/5 [==============================] - 0s 14ms/step - loss: 1.3140 - accuracy: 0.4167 - val_loss: 1.3026 - val_accuracy: 0.3750
# Epoch 4/50
# 5/5 [==============================] - 0s 14ms/step - loss: 1.2970 - accuracy: 0.3939 - val_loss: 1.2875 - val_accuracy: 0.5000
# Epoch 5/50
# 5/5 [==============================] - 0s 13ms/step - loss: 1.2451 - accuracy: 0.4470 - val_loss: 1.1745 - val_accuracy: 0.4375
# Epoch 6/50
# 5/5 [==============================] - 0s 13ms/step - loss: 1.1629 - accuracy: 0.5152 - val_loss: 1.1396 - val_accuracy: 0.4375
# Epoch 7/50
# 5/5 [==============================] - 0s 13ms/step - loss: 1.0858 - accuracy: 0.5833 - val_loss: 1.0372 - val_accuracy: 0.4688
# Epoch 8/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.9912 - accuracy: 0.5833 - val_loss: 1.0600 - val_accuracy: 0.4688
# Epoch 9/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.9500 - accuracy: 0.5833 - val_loss: 1.0779 - val_accuracy: 0.5000
# Epoch 10/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.9356 - accuracy: 0.6364 - val_loss: 1.0033 - val_accuracy: 0.5000
# Epoch 11/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.8615 - accuracy: 0.6742 - val_loss: 1.0877 - val_accuracy: 0.5625
# Epoch 12/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.9160 - accuracy: 0.6439 - val_loss: 0.8773 - val_accuracy: 0.6250
# Epoch 13/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.8726 - accuracy: 0.6742 - val_loss: 0.8951 - val_accuracy: 0.6250
# Epoch 14/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.8408 - accuracy: 0.6667 - val_loss: 0.7683 - val_accuracy: 0.7500
# Epoch 15/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.7913 - accuracy: 0.6970 - val_loss: 0.9167 - val_accuracy: 0.6562
# Epoch 16/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.8423 - accuracy: 0.6970 - val_loss: 0.7175 - val_accuracy: 0.7812
# Epoch 17/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.7835 - accuracy: 0.7500 - val_loss: 0.7728 - val_accuracy: 0.7188
# Epoch 18/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.7522 - accuracy: 0.7273 - val_loss: 0.6306 - val_accuracy: 0.7500
# Epoch 19/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.7718 - accuracy: 0.7045 - val_loss: 0.6740 - val_accuracy: 0.7188
# Epoch 20/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.7085 - accuracy: 0.7273 - val_loss: 0.7322 - val_accuracy: 0.7500
# Epoch 21/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6862 - accuracy: 0.7500 - val_loss: 0.5797 - val_accuracy: 0.7812
# Epoch 22/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.6665 - accuracy: 0.7576 - val_loss: 0.6011 - val_accuracy: 0.7812
# Epoch 23/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.6418 - accuracy: 0.7500 - val_loss: 0.5633 - val_accuracy: 0.6562
# Epoch 24/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.6238 - accuracy: 0.7500 - val_loss: 0.8045 - val_accuracy: 0.6875
# Epoch 25/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.6418 - accuracy: 0.7727 - val_loss: 0.6409 - val_accuracy: 0.6562
# Epoch 26/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.5844 - accuracy: 0.7652 - val_loss: 0.7879 - val_accuracy: 0.7500
# Epoch 27/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.5500 - accuracy: 0.7727 - val_loss: 0.6447 - val_accuracy: 0.7500
# Epoch 28/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.5867 - accuracy: 0.7879 - val_loss: 0.5830 - val_accuracy: 0.7500
# Epoch 29/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.6397 - accuracy: 0.7500 - val_loss: 0.4993 - val_accuracy: 0.7500
# Epoch 30/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.7095 - accuracy: 0.7348 - val_loss: 0.6825 - val_accuracy: 0.7812
# Epoch 31/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.6812 - accuracy: 0.7348 - val_loss: 0.6259 - val_accuracy: 0.7188
# Epoch 32/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.5845 - accuracy: 0.7727 - val_loss: 0.7387 - val_accuracy: 0.6562
# Epoch 33/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.5617 - accuracy: 0.7955 - val_loss: 0.6375 - val_accuracy: 0.7812
# Epoch 34/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.5827 - accuracy: 0.7803 - val_loss: 0.5185 - val_accuracy: 0.7500
# Epoch 35/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.5678 - accuracy: 0.8030 - val_loss: 0.5148 - val_accuracy: 0.7812
# Epoch 36/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.5147 - accuracy: 0.8182 - val_loss: 0.4889 - val_accuracy: 0.8125
# Epoch 37/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.5617 - accuracy: 0.7879 - val_loss: 0.7491 - val_accuracy: 0.7188
# Epoch 38/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.4890 - accuracy: 0.8182 - val_loss: 0.5992 - val_accuracy: 0.7812
# Epoch 39/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.4728 - accuracy: 0.8182 - val_loss: 0.5433 - val_accuracy: 0.8125
# Epoch 40/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.4745 - accuracy: 0.8258 - val_loss: 0.5339 - val_accuracy: 0.7812
# Epoch 41/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.4323 - accuracy: 0.8485 - val_loss: 0.4297 - val_accuracy: 0.8438
# Epoch 42/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.4000 - accuracy: 0.8864 - val_loss: 0.5534 - val_accuracy: 0.7500
# Epoch 43/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.4503 - accuracy: 0.8258 - val_loss: 0.4198 - val_accuracy: 0.7812
# Epoch 44/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.5735 - accuracy: 0.8030 - val_loss: 0.5260 - val_accuracy: 0.7188
# Epoch 45/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.4669 - accuracy: 0.8333 - val_loss: 0.5437 - val_accuracy: 0.7188
# Epoch 46/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.3918 - accuracy: 0.8788 - val_loss: 0.3445 - val_accuracy: 0.8438
# Epoch 47/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.4250 - accuracy: 0.8409 - val_loss: 0.5228 - val_accuracy: 0.7812
# Epoch 48/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.4068 - accuracy: 0.8561 - val_loss: 0.3745 - val_accuracy: 0.7812
# Epoch 49/50
# 5/5 [==============================] - 0s 12ms/step - loss: 0.4694 - accuracy: 0.8485 - val_loss: 0.4268 - val_accuracy: 0.7812
# Epoch 50/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.3571 - accuracy: 0.8864 - val_loss: 0.4269 - val_accuracy: 0.7812

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
predicted_batch = model.predict(ds_val)
tf.math.argmax(predicted_batch, axis=-1)
# Out:
# <tf.Tensor: shape=(32,), dtype=int64, numpy=
# array([0, 0, 3, 3, 0, 3, 0, 3, 0, 2, 3, 2, 2, 1, 1, 0, 3, 3, 1, 0, 1, 0,
#        2, 2, 1, 3, 0, 1, 3, 2, 3, 1], dtype=int64)>

# %%
image_batch, label_batch = next(iter(ds_val))

image_batch = image_batch.numpy()
label_batch = label_batch.numpy()

predicted_batch = model.predict(image_batch)
predicted_batch = tf.squeeze(predicted_batch).numpy()

predicted_ids = np.argmax(predicted_batch, axis=-1)
predicted_class_names = class_names[predicted_ids]

print(predicted_class_names)
# Out:
# ['battery' 'battery' 'phone' 'phone' 'battery' 'phone' 'battery' 'phone'
#  'battery' 'bulb' 'phone' 'bulb' 'bulb' 'controller' 'controller'
#  'battery' 'phone' 'phone' 'controller' 'battery' 'controller' 'battery'
#  'bulb' 'bulb' 'controller' 'phone' 'battery' 'controller' 'phone' 'bulb'
#  'phone' 'controller']

# %%
true_class_names=class_names[label_batch]
true_class_names
# Out:
# array(['controller', 'bulb', 'phone', 'phone', 'battery', 'phone', 'bulb',
#        'phone', 'controller', 'bulb', 'phone', 'bulb', 'bulb',
#        'controller', 'controller', 'battery', 'bulb', 'phone',
#        'controller', 'bulb', 'phone', 'battery', 'bulb', 'bulb',
#        'controller', 'phone', 'battery', 'controller', 'phone', 'bulb',
#        'phone', 'controller'], dtype='<U10')

# %%
print('True labels: ', label_batch)
print('Predicted labels: ', predicted_ids)
# Out:
# True labels:  [1 2 3 3 0 3 2 3 1 2 3 2 2 1 1 0 2 3 1 2 3 0 2 2 1 3 0 1 3 2 3 1]
# Predicted labels:  [0 0 3 3 0 3 0 3 0 2 3 2 2 1 1 0 3 3 1 0 1 0 2 2 1 3 0 1 3 2 3 1]

# %%
plt.figure(figsize=(10,20))
for n in range(27):
  plt.subplot(13,4,n+1)
  plt.subplots_adjust(hspace = 0.3)
  plt.imshow(image_batch[n].astype("uint8"))
  color = "blue" if predicted_ids[n] == label_batch[n] else "red"
  plt.title("{} ({})".format(predicted_class_names[n], true_class_names[n]), color=color)
  plt.axis('off')
_ = plt.suptitle("Model predictions (blue: correct, red: incorrect)")

# %%
model.save('saved_model_grayscale/my_model_grayscale')
# Out:
# INFO:tensorflow:Assets written to: saved_model_grayscale/my_model_grayscale\assets

# %%
acc
# Out:
# [0.280303031206131,
#  0.3333333432674408,
#  0.4166666567325592,
#  0.39393940567970276,
#  0.4469696879386902,
#  0.5151515007019043,
#  0.5833333134651184,
#  0.5833333134651184,
#  0.5833333134651184,
#  0.6363636255264282,
#  0.6742424368858337,
#  0.6439393758773804,
#  0.6742424368858337,
#  0.6666666865348816,
#  0.6969696879386902,
#  0.6969696879386902,
#  0.75,
#  0.7272727489471436,
#  0.7045454382896423,
#  0.7272727489471436,
#  0.75,
#  0.7575757503509521,
#  0.75,
#  0.75,
#  0.7727272510528564,
#  0.7651515007019043,
#  0.7727272510528564,
#  0.7878788113594055,
#  0.75,
#  0.7348484992980957,
#  0.7348484992980957,
#  0.7727272510528564,
#  0.7954545617103577,
#  0.7803030014038086,
#  0.8030303120613098,
#  0.8181818127632141,
#  0.7878788113594055,
#  0.8181818127632141,
#  0.8181818127632141,
#  0.8257575631141663,
#  0.8484848737716675,
#  0.8863636255264282,
#  0.8257575631141663,
#  0.8030303120613098,
#  0.8333333134651184,
#  0.8787878751754761,
#  0.8409090638160706,
#  0.8560606241226196,
#  0.8484848737716675,
#  0.8863636255264282]

# %%
val_acc
# Out:
# [0.3125,
#  0.46875,
#  0.375,
#  0.5,
#  0.4375,
#  0.4375,
#  0.46875,
#  0.46875,
#  0.5,
#  0.5,
#  0.5625,
#  0.625,
#  0.625,
#  0.75,
#  0.65625,
#  0.78125,
#  0.71875,
#  0.75,
#  0.71875,
#  0.75,
#  0.78125,
#  0.78125,
#  0.65625,
#  0.6875,
#  0.65625,
#  0.75,
#  0.75,
#  0.75,
#  0.75,
#  0.78125,
#  0.71875,
#  0.65625,
#  0.78125,
#  0.75,
#  0.78125,
#  0.8125,
#  0.71875,
#  0.78125,
#  0.8125,
#  0.78125,
#  0.84375,
#  0.75,
#  0.78125,
#  0.71875,
#  0.71875,
#  0.84375,
#  0.78125,
#  0.78125,
#  0.78125,
#  0.78125]
